# %% [markdown]
# # Web Scrapping Assignment 4

# %% [markdown]
# Name:-Parth Gadhvi
#
# Batch:- 2307

# %% [markdown]
# ## Questions

# %% [markdown]
# 1. Scrape the details of most viewed videos on YouTube from Wikipedia. Url =
# https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos You need to find following details:
#
#  A) Rank
#
#  B) Name
#
#  C) Artist
#
#  D) Upload date
#
#  E) Views

# %%
# Importing Libraries
import pandas as pd
import selenium                                  
from bs4 import BeautifulSoup
from selenium import webdriver                   
from selenium.webdriver.common.by import By      

import warnings                                  
warnings.filterwarnings("ignore")

import time                                      
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service

#Importing required exceptions which needs to be handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# Let's Install automated chrome browser and connect it to web driver
driver = webdriver.Chrome(service=Service())

#maximise the window
driver.maximize_window()

# %%
#opening the website page
driver.get("https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos")

# %%
#Extracting Rank
rank=[i.text.strip('.') for i in driver.find_elements(By.XPATH,'//tbody/tr/td[1]')[:30]]

#Extracting Name
name =[i.text.split('[')[0] for i in driver.find_elements(By.XPATH,'//tr/td[2]')[:30]]

#Extracting Artist
artist = [i.text for i in driver.find_elements(By.XPATH,'//tr/td[3]')[:30]]

#extracting views
viewsBillions =[i.text for i in driver.find_elements(By.XPATH,'//tr/td[4]')[:30]]

#extracting Upload Date
uploadDate=[i.text for i in driver.find_elements(By.XPATH,'//tr/td[5]')[:30]]

driver.close()

print(len(rank),len(name),len(artist),len(viewsBillions),len(uploadDate))
# Out:
# 30 30 30 30 30

# %%
Most_viewed_videos_on_YouTube = pd.DataFrame({
    "Rank":rank,
    "Name": name,
    "Artist": artist,
    "Upload Date": uploadDate,
    "Views In Billions": viewsBillions
})

#set rank as index
Most_viewed_videos_on_YouTube = Most_viewed_videos_on_YouTube.set_index('Rank')
Most_viewed_videos_on_YouTube
# Out:
#                                                    Name  \
# Rank
#       This section's factual accuracy may be comprom...
# 1                                    "Baby Shark Dance"
# 2                                           "Despacito"
# 3                                "Johny Johny Yes Papa"
# 4                                           "Bath Song"
# 5                                        "Shape of You"
# 6                                       "See You Again"
# 7                                   "Wheels on the Bus"
# 8                         "Phonics Song with Two Words"
# 9                                         "Uptown Funk"
# 10          "Learning Colors – Colorful Eggs on a Farm"
# 11                                      "Gangnam Style"
# 12           "Masha and the Bear – Recipe for Disaster"
# 13                                     "Dame Tu Cosita"
# 14                                             "Axel F"
# 15                                              "Sugar"
# 16                                     "Counting Stars"
# 17                                               "Roar"
# 18                                "Baa Baa Black Sheep"
# 19                   "Waka Waka (This Time for Africa)"
# 20                                              "Sorry"
# 21                                     "Lakdi Ki Kathi"
# 22                                  "Thinking Out Loud"
# 23                                         "Dark Horse"
# 24                  "Humpty the train on a fruits ride"
# 25                                            "Perfect"
# 26                                              "Faded"
# 27                                         "Let Her Go"
# 28                                     "Girls Like You"
# 29                                            "Lean On"
#
#                                                  Artist        Upload Date  \
# Rank
#             Pinkfong Baby Shark - Kids' Songs & Stories      June 17, 2016
# 1                                            Luis Fonsi   January 12, 2017
# 2     LooLoo Kids - Nursery Rhymes and Children's Songs    October 8, 2016
# 3                            Cocomelon - Nursery Rhymes        May 2, 2018
# 4                                            Ed Sheeran   January 30, 2017
# 5                                           Wiz Khalifa      April 6, 2015
# 6                            Cocomelon - Nursery Rhymes       May 24, 2018
# 7                 ChuChu TV Nursery Rhymes & Kids Songs      March 6, 2014
# 8                                           Mark Ronson  November 19, 2014
# 9                                           Miroshka TV  February 27, 2018
# 10                                          officialpsy      July 15, 2012
# 11                                           Get Movies   January 31, 2012
# 12                                        Ultra Records      April 5, 2018
# 13                                           Crazy Frog      June 16, 2009
# 14                                             Maroon 5   January 14, 2015
# 15                                          OneRepublic       May 31, 2013
# 16                                           Katy Perry  September 5, 2013
# 17                           Cocomelon - Nursery Rhymes      June 25, 2018
# 18                                              Shakira       June 4, 2010
# 19                                        Justin Bieber   October 22, 2015
# 20                                         Jingle Toons      June 14, 2018
# 21                                           Ed Sheeran    October 7, 2014
# 22                                           Katy Perry  February 20, 2014
# 23        Kiddiestv Hindi - Nursery Rhymes & Kids Songs   January 26, 2018
# 24                                           Ed Sheeran   November 9, 2017
# 25                                          Alan Walker   December 3, 2015
# 26                                            Passenger      July 25, 2012
# 27                                             Maroon 5       May 31, 2018
# 28                                 Major Lazer Official     March 22, 2015
# 29                                     Enrique Iglesias     April 11, 2014
#
#      Views In Billions
# Rank
#                  13.36
# 1                 8.26
# 2                 6.80
# 3                 6.41
# 4                 6.08
# 5                 6.03
# 6                 5.56
# 7                 5.48
# 8                 5.03
# 9                 4.97
# 10                4.90
# 11                4.56
# 12                4.44
# 13                4.06
# 14                3.93
# 15                3.87
# 16                3.87
# 17                3.78
# 18                3.73
# 19                3.71
# 20                3.69
# 21                3.66
# 22                3.59
# 23                3.55
# 24                3.54
# 25                3.51
# 26                3.51
# 27                3.48
# 28                3.46
# 29                3.45

# %% [markdown]
# 2. Scrape the details team India’s international fixtures from bcci.tv.
# Url = https://www.bcci.tv/.
# You need to find following details:
#
#  A) Match title (I.e. 1 ODI)
#
#  B) Series
#
#  C) Place
#
#  D) Date
#
#  E) Time
#
#  Note: - From bcci.tv home page you have reach to the international fixture page through code.

# %%
# Importing Libraries
import pandas as pd
import selenium                                  
from bs4 import BeautifulSoup
from selenium import webdriver                   
from selenium.webdriver.common.by import By      

import warnings                                  
warnings.filterwarnings("ignore")

import time                                      
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service

#Importing required exceptions which needs to be handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException, ElementClickInterceptedException

# Let's Install automated chrome browser and connect it to web driver
driver = webdriver.Chrome(service=Service())

#maximise the window
driver.maximize_window()

#opening the website page
driver.get("https://www.bcci.tv/")

# %%
#opening the International Page
international = driver.find_element(By.XPATH,'/html/body/nav/div[1]/div[2]/ul[1]/li[2]/a')
international.click()

# %%
#accepting cooking
try:
    cookie=driver.find_element(By.XPATH,'//button[@class="cookie__accept btn btn-primary"]')
    cookie.click()
except NoSuchElementException:
    print('No Exception Occured')

# CLicking more button
while(True):
    try:
        more = driver.find_element(By.XPATH,'//button[@class="match-btn btn-red d-flex align-items-center justify-content-center mx-auto mt-3"]')
        more.click()
    except NoSuchElementException:
        break
        
#Extracting match Title
match=[i.text.strip(' -') for i in driver.find_elements(By.XPATH,'//span[@class="matchOrderText ng-binding ng-scope"]')]

#Extracting Series
series = [i.text for i in driver.find_elements(By.XPATH,'//h5[@class="match-tournament-name ng-binding"]')]

#Extracting Place
place = [i.text.split(' -')[1] for i in driver.find_elements(By.XPATH,'//div[@class="match-place ng-scope"]')]

# Extracting Date
date = [i.text for i in driver.find_elements(By.XPATH,'//div[@class="match-dates ng-binding"]')]

# Extracting Time
time = [i.text for i in driver.find_elements(By.XPATH,'//div[@class="match-time no-margin ng-binding"]')]

driver.close()

print(len(match),len(series),len(place),len(date),len(time))

internationalfixtures=pd.DataFrame({
    "Match Title": match,
    "Series": series,
    "Place": place,
    "Date": date,
    "Time":time
})
internationalfixtures
# Out:
# 37 37 37 37 37
#         Match Title                                   Series  \
# 0   Quarter Final 1           19TH ASIAN GAMES HANGZHOU 2022
# 1           1st ODI          AUSTRALIA TOUR OF INDIA 2023-24
# 2           2nd ODI          AUSTRALIA TOUR OF INDIA 2023-24
# 3           3rd ODI          AUSTRALIA TOUR OF INDIA 2023-24
# 4           1st ODI  ICC MENS WORLD CUP 2023 WARM-UP MATCHES
# 5          1st T20I           19TH ASIAN GAMES HANGZHOU 2022
# 6           2nd ODI  ICC MENS WORLD CUP 2023 WARM-UP MATCHES
# 7           1st ODI                  ICC MENS WORLD CUP 2023
# 8           2nd ODI                  ICC MENS WORLD CUP 2023
# 9           3rd ODI                  ICC MENS WORLD CUP 2023
# 10          4th ODI                  ICC MENS WORLD CUP 2023
# 11          5th ODI                  ICC MENS WORLD CUP 2023
# 12          6th ODI                  ICC MENS WORLD CUP 2023
# 13          7th ODI                  ICC MENS WORLD CUP 2023
# 14          8th ODI                  ICC MENS WORLD CUP 2023
# 15          9th ODI                  ICC MENS WORLD CUP 2023
# 16         1st T20I          AUSTRALIA TOUR OF INDIA 2023-24
# 17         2nd T20I          AUSTRALIA TOUR OF INDIA 2023-24
# 18         3rd T20I          AUSTRALIA TOUR OF INDIA 2023-24
# 19         4th T20I          AUSTRALIA TOUR OF INDIA 2023-24
# 20         5th T20I          AUSTRALIA TOUR OF INDIA 2023-24
# 21         1st T20I       INDIA TOUR OF SOUTH AFRICA 2023-24
# 22         2nd T20I       INDIA TOUR OF SOUTH AFRICA 2023-24
# 23         3rd T20I       INDIA TOUR OF SOUTH AFRICA 2023-24
# 24          1st ODI       INDIA TOUR OF SOUTH AFRICA 2023-24
# 25          2nd ODI       INDIA TOUR OF SOUTH AFRICA 2023-24
# 26          3rd ODI       INDIA TOUR OF SOUTH AFRICA 2023-24
# 27         1st Test       INDIA TOUR OF SOUTH AFRICA 2023-24
# 28         2nd Test       INDIA TOUR OF SOUTH AFRICA 2023-24
# 29         1st T20I        AFGHANISTAN TOUR OF INDIA 2023-24
# 30         2nd T20I        AFGHANISTAN TOUR OF INDIA 2023-24
# 31         3rd T20I        AFGHANISTAN TOUR OF INDIA 2023-24
# 32         1st Test            ENGLAND TOUR OF INDIA 2023-24
# 33         2nd Test            ENGLAND TOUR OF INDIA 2023-24
# 34         3rd Test            ENGLAND TOUR OF INDIA 2023-24
# 35         4th Test            ENGLAND TOUR OF INDIA 2023-24
# 36         5th Test            ENGLAND TOUR OF INDIA 2023-24
#
#                                                 Place         Date  \
# 0                    Pingfeng Cricket Field, Hangzhou  21 SEP 2023
# 1    Punjab Cricket Association IS Bindra Stadium,...  22 SEP 2023
# 2                      Holkar Cricket Stadium, Indore  24 SEP 2023
# 3      Saurashtra Cricket Association Stadium, Rajkot  27 SEP 2023
# 4                 Barsapara Cricket Stadium, Guwahati  30 SEP 2023
# 5                    Pingfeng Cricket Field, Hangzhou   3 OCT 2023
# 6    Greenfield International Stadium, Thiruvanant...   3 OCT 2023
# 7                     MA Chidambaram Stadium, Chennai   8 OCT 2023
# 8                         Arun Jaitley Stadium, Delhi  11 OCT 2023
# 9                    Narendra Modi Stadium, Ahmedabad  14 OCT 2023
# 10      Maharashtra Cricket Association Stadium, Pune  19 OCT 2023
# 11   Himachal Pradesh Cricket Association Stadium,...  22 OCT 2023
# 12   Bharat Ratna Shri Atal Bihari Vajpayee Ekana ...  29 OCT 2023
# 13                           Wankhede Stadium, Mumbai   2 NOV 2023
# 14                              Eden Gardens, Kolkata   5 NOV 2023
# 15                   M Chinnaswamy Stadium, Bengaluru  12 NOV 2023
# 16   Dr YS Rajasekhara Reddy ACA-VDCA Cricket Stad...  23 NOV 2023
# 17   Greenfield International Stadium, Thiruvanant...  26 NOV 2023
# 18                Barsapara Cricket Stadium, Guwahati  28 NOV 2023
# 19       Vidarbha Cricket Association Stadium, Nagpur   1 DEC 2023
# 20      Rajiv Gandhi International Stadium, Hyderabad   3 DEC 2023
# 21                                  Kingsmead, Durban  10 DEC 2023
# 22                         St George's Park, Gqeberha  12 DEC 2023
# 23                The Wanderers Stadium, Johannesburg  14 DEC 2023
# 24                                       Johannesburg  17 DEC 2023
# 25                         St George's Park, Gqeberha  19 DEC 2023
# 26                                 Boland Park, Paarl  21 DEC 2023
# 27                         SuperSport Park, Centurion  26 DEC 2023
# 28                                Newlands, Cape Town   3 JAN 2024
# 29   Punjab Cricket Association IS Bindra Stadium,...  11 JAN 2024
# 30                     Holkar Cricket Stadium, Indore  14 JAN 2024
# 31                   M Chinnaswamy Stadium, Bengaluru  17 JAN 2024
# 32      Rajiv Gandhi International Stadium, Hyderabad  25 JAN 2024
# 33   Dr YS Rajasekhara Reddy ACA-VDCA Cricket Stad...   2 FEB 2024
# 34     Saurashtra Cricket Association Stadium, Rajkot  15 FEB 2024
# 35         JSCA International Stadium Complex, Ranchi  23 FEB 2024
# 36   Himachal Pradesh Cricket Association Stadium,...   7 MAR 2024
#
#            Time
# 0   6:30 AM IST
# 1   1:30 PM IST
# 2   1:30 PM IST
# 3   1:30 PM IST
# 4   2:00 PM IST
# 5   6:30 AM IST
# 6   2:00 PM IST
# 7   2:00 PM IST
# 8   2:00 PM IST
# 9   2:00 PM IST
# 10  2:00 PM IST
# 11  2:00 PM IST
# 12  2:00 PM IST
# 13  2:00 PM IST
# 14  2:00 PM IST
# 15  2:00 PM IST
# 16  7:00 PM IST
# 17  7:00 PM IST
# 18  7:00 PM IST
# 19  7:00 PM IST
# 20  7:00 PM IST
# 21  9:30 PM IST
# 22  9:30 PM IST
# 23  9:30 PM IST
# 24  2:00 PM IST
# 25  2:00 PM IST
# 26  2:00 PM IST
# 27  1:30 PM IST
# 28  1:30 PM IST
# 29  7:00 PM IST
# 30  7:00 PM IST
# 31  7:00 PM IST
# 32  9:30 AM IST
# 33  9:30 AM IST
# 34  9:30 AM IST
# 35  9:30 AM IST
# 36  9:30 AM IST

# %% [markdown]
# 3. Scrape the details of State-wise GDP of India from statisticstime.com.
# Url = http://statisticstimes.com/
# You have to find following details:
#  A)Rank
#
#  B) State
#
#  C) GSDP(18-19)- at current prices
#
#  D) GSDP(19-20)- at current prices
#
#  E) Share(18-19)
#
#  F) GDP($ billion)
#
#  Note: - From statisticstimes home page you have to reach to economy page through code.

# %%
# Importing Libraries
import pandas as pd
import selenium                                  
from bs4 import BeautifulSoup
from selenium import webdriver                   
from selenium.webdriver.common.by import By      

import warnings                                  
warnings.filterwarnings("ignore")

import time                                      
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service

#Importing required exceptions which needs to be handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException, ElementClickInterceptedException

# Let's Install automated chrome browser and connect it to web driver
driver = webdriver.Chrome(service=Service())

#maximise the window
driver.maximize_window()

#opening the website page
driver.get("https://www.statisticstimes.com/")

# %%
#clicking Economy
economy=driver.find_element(By.XPATH,'/html/body/div[2]/div[1]/div[2]/div[2]/button')
economy.click()

#Clicking on India
india=driver.find_element(By.XPATH,'//div[@class="dropdown-content"]/a[3]')
india.click()

# %%
GDP=driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[2]/ul/li[1]/a')
GDP.click()

#Extracting the details
rank = []
state = []
gsdp_18 = []
gsdp_19 = []
shares = []
gdp = []

#Extracting the rank details
try:
    rank_tags = driver.find_elements(By.XPATH,"//div[@id = 'table_id_wrapper']/table/tbody/tr/td[1]")
    for ra in rank_tags:
        rank.append(ra.text)
except NoSuchElementException:
    Company.append('NA')
    
#Extracting state name details
try:
    state_tags = driver.find_elements(By.XPATH,"//div[@id = 'table_id_wrapper']/table/tbody/tr/td[2]")
    for st in state_tags:
        state.append(st.text)
except NoSuchElementException:
    Company.append('NA')

#Extracting gsdp 2019-20
try:
    gsdp_19_tags = driver.find_elements(By.XPATH,"//div[@id = 'table_id_wrapper']/table/tbody/tr/td[3]")
    for g in gsdp_19_tags:
        gsdp_19.append(g.text)
except NoSuchElementException:
    Company.append('NA')

#Extracting gsdp 2018-19
try:
    gsdp_18_tags = driver.find_elements(By.XPATH,"//div[@id = 'table_id_wrapper']/table/tbody/tr/td[4]")
    for gs in gsdp_18_tags:
        gsdp_18.append(gs.text)
except NoSuchElementException:
    Company.append('NA')
    
#Extracting share details
try:
    shares_tags = driver.find_elements(By.XPATH,"//div[@id = 'table_id_wrapper']/table/tbody/tr/td[5]")
    for sh in shares_tags:
        shares.append(sh.text)
except NoSuchElementException:
    Company.append('NA')

#Extracting GDP details
try:
    gdp_tags = driver.find_elements(By.XPATH,"//div[@id = 'table_id_wrapper']/table/tbody/tr/td[6]")
    for gd in gdp_tags:
        gdp.append(gd.text)
except NoSuchElementException:
    Company.append('NA')

gdp_india = pd.DataFrame({'Rank':rank,'State':state,'GSDP 2019-20(Cr INR at Current Price)':gsdp_19,'GSDP 2018-19(Cr INR at Current Price)':gsdp_18,'Share(%)':shares,'GDP($billion)':gdp})
gdp_india
# Out:
#    Rank                      State GSDP 2019-20(Cr INR at Current Price)  \
# 0     1                Maharashtra                                     -
# 1     2                 Tamil Nadu                             1,845,853
# 2     3              Uttar Pradesh                             1,687,818
# 3     4                    Gujarat                                     -
# 4     5                  Karnataka                             1,631,977
# 5     6                West Bengal                             1,253,832
# 6     7                  Rajasthan                             1,020,989
# 7     8             Andhra Pradesh                               972,782
# 8     9                  Telangana                               969,604
# 9    10             Madhya Pradesh                               906,672
# 10   11                     Kerala                                     -
# 11   12                      Delhi                               856,112
# 12   13                    Haryana                               831,610
# 13   14                      Bihar                               611,804
# 14   15                     Punjab                               574,760
# 15   16                     Odisha                               521,275
# 16   17                      Assam                                     -
# 17   18               Chhattisgarh                               329,180
# 18   19                  Jharkhand                               328,598
# 19   20                Uttarakhand                                     -
# 20   21            Jammu & Kashmir                                     -
# 21   22           Himachal Pradesh                               165,472
# 22   23                        Goa                                80,449
# 23   24                    Tripura                                55,984
# 24   25                 Chandigarh                                     -
# 25   26                 Puducherry                                38,253
# 26   27                  Meghalaya                                36,572
# 27   28                     Sikkim                                32,496
# 28   29                    Manipur                                31,790
# 29   30                   Nagaland                                     -
# 30   31          Arunachal Pradesh                                     -
# 31   32                    Mizoram                                26,503
# 32   33  Andaman & Nicobar Islands                                     -
#
#    GSDP 2018-19(Cr INR at Current Price) Share(%) GDP($billion)
# 0                              2,632,792   13.94%       399.921
# 1                              1,630,208    8.63%       247.629
# 2                              1,584,764    8.39%       240.726
# 3                              1,502,899    7.96%       228.290
# 4                              1,493,127    7.91%       226.806
# 5                              1,089,898    5.77%       165.556
# 6                                942,586    4.99%       143.179
# 7                                862,957    4.57%       131.083
# 8                                861,031    4.56%       130.791
# 9                                809,592    4.29%       122.977
# 10                               781,653    4.14%       118.733
# 11                               774,870    4.10%       117.703
# 12                               734,163    3.89%       111.519
# 13                               530,363    2.81%        80.562
# 14                               526,376    2.79%        79.957
# 15                               487,805    2.58%        74.098
# 16                               315,881    1.67%        47.982
# 17                               304,063    1.61%        46.187
# 18                               297,204    1.57%        45.145
# 19                               245,895    1.30%        37.351
# 20                               155,956    0.83%        23.690
# 21                               153,845    0.81%        23.369
# 22                                73,170    0.39%        11.115
# 23                                49,845    0.26%         7.571
# 24                                42,114    0.22%         6.397
# 25                                34,433    0.18%         5.230
# 26                                33,481    0.18%         5.086
# 27                                28,723    0.15%         4.363
# 28                                27,870    0.15%         4.233
# 29                                27,283    0.14%         4.144
# 30                                24,603    0.13%         3.737
# 31                                22,287    0.12%         3.385
# 32                                     -        -             -

# %% [markdown]
# 4. Scrape the details of trending repositories on Github.com.
# Url = https://github.com/
# You have to find the following details:
#
#
#   A) Repository title
#
#   B) Repository description
#
#   C) Contributors count
#
#   D) Language used
#
#   Note: - From the home page you have to click on the trending option from Explore menu through code.

# %%
# Importing Libraries
import pandas as pd
import selenium                                  
from bs4 import BeautifulSoup
from selenium import webdriver                   
from selenium.webdriver.common.by import By      

import warnings                                  
warnings.filterwarnings("ignore")

import time                                      
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service

#Importing required exceptions which needs to be handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException, ElementClickInterceptedException

# Let's Install automated chrome browser and connect it to web driver
driver = webdriver.Chrome(service=Service())

#maximise the window
driver.maximize_window()

#opening the website page
driver.get("https://github.com/")

# %%
#Clicking Open Source
source =driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/button')
source.click()

#clicking Trending
trending=driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/div/div[3]/ul/li[2]/a')
trending.click()

# %%
#Extracting title
title=[i.text for i in driver.find_elements(By.XPATH,'//h2[@class="h3 lh-condensed"]')]

#Extracting Description
description = []

for item in driver.find_elements(By.XPATH, '//article[@class="Box-row"]'):
    try:
        des = item.find_element(By.XPATH, './/p[@class="col-9 color-fg-muted my-1 pr-4"]')
        description.append(des.text)
    except NoSuchElementException:
        description.append('-')
        
#Extracting Contributors count
count=[i.text for i in driver.find_elements(By.XPATH,'//div[@class="f6 color-fg-muted mt-2"]/a')]
contri=count[::2]

#Extracting Language
lang = []
for items in driver.find_elements(By.XPATH,'//div[@class="f6 color-fg-muted mt-2"]'):
    try:
        l= items.find_element(By.XPATH,'./span/span[2]')
        lang.append(l.text)
    except NoSuchElementException:
        lang.append('-')
        
driver.close()
print(len(title), len(description), len(contri), len(lang))

#Converting it into DataFrame:
trending_repositories = pd.DataFrame({
    "Repository Title":title,
    "Repository Description": description,
    "Contributors Count" : contri,
    "Language" : lang
})

trending_repositories
# Out:
# 25 25 25 25
#                          Repository Title  \
# 0                     hyperdxio / hyperdx
# 1      williamyang1991 / Rerender_A_Video
# 2                     NExT-GPT / NExT-GPT
# 3                       makeplane / plane
# 4                         grafana / beyla
# 5     CorentinJ / Real-Time-Voice-Cloning
# 6                     mastodon / mastodon
# 7   AntonioErdeljac / next13-lms-platform
# 8                         TabbyML / tabby
# 9                        basecamp / kamal
# 10                    godotengine / godot
# 11                       vercel / next.js
# 12               ripienaar / free-for-dev
# 13                    aiwaves-cn / agents
# 14             duckduckgo / tracker-radar
# 15                  Alamofire / Alamofire
# 16                         coqui-ai / TTS
# 17                    sczhou / ProPainter
# 18        aras-p / UnityGaussianSplatting
# 19                 Snailclimb / JavaGuide
# 20        WooooDyy / LLM-Agent-Paper-List
# 21        MunGell / awesome-for-beginners
# 22                           fmtlib / fmt
# 23                      meshery / meshery
# 24               langchain-ai / langchain
#
#                                Repository Description Contributors Count  \
# 0   Resolve production issues, fast. An open sourc...              2,452
# 1   [SIGGRAPH Asia 2023] Rerender A Video: Zero-Sh...              1,076
# 2   Code and models for NExT-GPT: Any-to-Any Multi...                773
# 3   🔥 🔥 🔥 Open Source JIRA, Linear and Height Alte...             15,477
# 4   eBPF-based autoinstrumentation of HTTP and HTT...                428
# 5   Clone a voice in 5 seconds to generate arbitra...             45,098
# 6   Your self-hosted, globally interconnected micr...             43,926
# 7                                                   -                115
# 8                     Self-hosted AI coding assistant              9,960
# 9                           Deploy web apps anywhere.              6,761
# 10  Godot Engine – Multi-platform 2D and 3D game e...             73,500
# 11                                The React Framework            111,749
# 12  A list of SaaS, PaaS and IaaS offerings that h...             73,720
# 13  An Open-source Framework for Autonomous Langua...              2,070
# 14  Data set of top third party web domains with r...              1,182
# 15                   Elegant HTTP Networking in Swift             39,756
# 16  🐸💬 - a deep learning toolkit for Text-to-Speec...             18,409
# 17  [ICCV 2023] ProPainter: Improving Propagation ...                735
# 18      Toy Gaussian Splatting visualization in Unity                521
# 19  「Java学习+面试指南」一份涵盖大部分 Java 程序员所需要掌握的核心知识。准备 Jav...            137,187
# 20  The paper list of the 86-page paper "The Rise ...              1,099
# 21     A list of awesome beginners-friendly projects.             56,617
# 22                        A modern formatting library             17,757
# 23                  Meshery, the cloud native manager              3,246
# 24  ⚡ Building applications with LLMs through comp...             62,583
#
#             Language
# 0         TypeScript
# 1   Jupyter Notebook
# 2             Python
# 3         TypeScript
# 4                  C
# 5             Python
# 6               Ruby
# 7         TypeScript
# 8         TypeScript
# 9               Ruby
# 10               C++
# 11        JavaScript
# 12              HTML
# 13            Python
# 14        JavaScript
# 15             Swift
# 16            Python
# 17            Python
# 18                C#
# 19              Java
# 20                 -
# 21                 -
# 22               C++
# 23                Go
# 24            Python

# %% [markdown]
# 5. Scrape the details of top 100 songs on billiboard.com. Url = https:/www.billboard.com/
# You have to find the following details:
#
#   A) Song name
#
#   B) Artist name
#
#   C) Last week rank
#
#   D) Peak rank
#
#   E) Weeks on board
#
#   Note: - From the home page you have to click on the charts option then hot 100-page link through code.

# %%
# Importing Libraries
import pandas as pd
import selenium                                  
from bs4 import BeautifulSoup
from selenium import webdriver                   
from selenium.webdriver.common.by import By      

import warnings                                  
warnings.filterwarnings("ignore")

import time                                      
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service

#Importing required exceptions which needs to be handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException, ElementClickInterceptedException

# Let's Install automated chrome browser and connect it to web driver
driver = webdriver.Chrome(service=Service())

#maximise the window
driver.maximize_window()

#opening the website page
driver.get("https://www.billboard.com/")

# %%
#Clicking on the menu
menu=driver.find_element(By.XPATH,'/html/body/div[3]/header/div/div[2]/div/div/div[1]/div[1]/button')
menu.click()

#Clicking top 100
top = driver.find_element(By.XPATH,'/html/body/div[3]/div[9]/div/div/div/ul/li[1]/ul/li[2]/a')
top.click()

#Extracting Required Data
data=[i.text.split('\n') for i in driver.find_elements(By.XPATH,'//li[@class="lrv-u-width-100p"]')]

driver.close()

#Creating DataFrame:
columns = ['Song name', 'Artist Name', 'Last Weak Rank', 'Peak Rank', 'Weeks on Chart']

Top100 = pd.DataFrame(data, columns=columns)
Top100
# Out:
#                       Song name                           Artist Name  \
# 0                       Vampire                        Olivia Rodrigo
# 1            Paint The Town Red                              Doja Cat
# 2         I Remember Everything  Zach Bryan Featuring Kacey Musgraves
# 3                      Fast Car                            Luke Combs
# 4                  Cruel Summer                          Taylor Swift
# ..                          ...                                   ...
# 95                      Lagunas             Peso Pluma & Jasiel Nunez
# 96  Sittin' On Top Of The World                             Burna Boy
# 97                      Rubicon                            Peso Pluma
# 98                          TQM                         Fuerza Regida
# 99                     Amargura                               Karol G
#
#    Last Weak Rank Peak Rank Weeks on Chart
# 0               9         1             11
# 1               1         1              6
# 2               2         1              3
# 3               3         2             25
# 4               4         3             19
# ..            ...       ...            ...
# 95              -        77              9
# 96             86        80              3
# 97             95        63             11
# 98             89        34             17
# 99             91        85              5
#
# [100 rows x 5 columns]

# %% [markdown]
# 6. Scrape the details of Highest selling novels.
# compare
#
#   A) Book name
#
#   B) Author name
#
#   C) Volumes sold
#
#   D) Publisher
#
#   E) Genre
#
#   url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare

# %%
# Importing Libraries
import pandas as pd
import selenium                                  
from bs4 import BeautifulSoup
from selenium import webdriver                   
from selenium.webdriver.common.by import By      

import warnings                                  
warnings.filterwarnings("ignore")

import time                                      
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service

#Importing required exceptions which needs to be handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException, ElementClickInterceptedException

# Let's Install automated chrome browser and connect it to web driver
driver = webdriver.Chrome(service=Service())

#maximise the window
driver.maximize_window()

#opening the website page
driver.get('https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare')

# %%
#Extracting Book Name
book =[i.text for i in driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[2]')]

#Extracting Author Name
author = [i.text for i in driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[3]')]

#Extracting Volumes sold
vol = [i.text for i in driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[4]')]

#Extracting Publisher
pub = [i.text for i in driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[5]')]

#Extracting Genre
gen = [i.text for i in driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[6]')]

driver.close()
print(len(book),len(author),len(vol),len(pub), len(gen))

# Convertingin Dataframe:
Highest_selling_novels=pd.DataFrame({
    "Book Name": book,
    "Author Name":author,
    "Volumes sold":vol,
    "Publisher": pub,
    "Genre" : gen
})

Highest_selling_novels
# Out:
# 100 100 100 100 100
#                                             Book Name       Author Name  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volumes sold        Publisher                        Genre
# 0     5,094,805       Transworld  Crime, Thriller & Adventure
# 1     4,475,152       Bloomsbury           Children's Fiction
# 2     4,200,654       Bloomsbury           Children's Fiction
# 3     4,179,479       Bloomsbury           Children's Fiction
# 4     3,758,936     Random House              Romance & Sagas
# ..          ...              ...                          ...
# 95      807,311     Random House   General & Literary Fiction
# 96      794,201          Penguin        Food & Drink: General
# 97      792,187  Scholastic Ltd.          Young Adult Fiction
# 98      791,507            Orion           Biography: General
# 99      791,095          Penguin        Food & Drink: General
#
# [100 rows x 5 columns]

# %% [markdown]
# 7. Scrape the details most watched tv series of all time from imdb.com.
# Url = https://www.imdb.com/list/ls095964455/ You
# have to find the following details:
#
#
#   A) Name
#
#   B) Year span
#
#   C) Genre
#
#   D) Run time
#
#   E) Ratings
#
#   F) Votes

# %%
# Importing Libraries
import pandas as pd
import selenium                                  
from bs4 import BeautifulSoup
from selenium import webdriver                   
from selenium.webdriver.common.by import By      

import warnings                                  
warnings.filterwarnings("ignore")

import time                                      
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service

#Importing required exceptions which needs to be handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException, ElementClickInterceptedException

# Let's Install automated chrome browser and connect it to web driver
driver = webdriver.Chrome(service=Service())

#maximise the window
driver.maximize_window()

#opening the website page
driver.get("https://www.imdb.com/list/ls095964455/")

# %%
#Extracting Name:
name =[i.text for i in driver.find_elements(By.XPATH,'//h3[@class="lister-item-header"]/a')]

# Extracting Year Span
year = [i.text for i in driver.find_elements(By.XPATH,'//span[@class="lister-item-year text-muted unbold"]')]

#Extracting Genre 
genre = [i.text for i in driver.find_elements(By.XPATH,'//p[@class="text-muted text-small"]/span[5]')]

#Extracting Run time
time = [i.text for i in driver.find_elements(By.XPATH,'//p[@class="text-muted text-small"]/span[3]')]

#Extracting Rating
rating = [i.text for i in driver.find_elements(By.XPATH,'//div[@class="ipl-rating-widget"]/div/span[2]')]

#Extracting Votes
voting = [i.text for i in driver.find_elements(By.XPATH,'//p[@class="text-muted text-small"][3]/span[2]')]

driver.close()
print(len(name), len(year), len(genre), len(time), len(rating),len(voting))

#Creating DataFrame
most_watched_tv_series=pd.DataFrame({
    "Name": name,
    "Year span":year,
    "Genre":genre,
    "Run time":time,
    "Ratings":rating,
    "Votes": voting
})
most_watched_tv_series
# Out:
# 100 100 100 100 100 100
#                               Name    Year span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things  (2016–2025)    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)                     Drama
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds     (2005– )     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    Run time Ratings      Votes
# 0    57 min     9.2  2,205,249
# 1    51 min     8.7  1,276,583
# 2    44 min     8.1  1,046,328
# 3    60 min     7.5    307,522
# 4    43 min     7.6    266,599
# ..      ...     ...        ...
# 95   42 min     7.5     52,755
# 96   50 min     7.8     64,813
# 97   42 min     8.1    211,126
# 98   45 min       7     43,925
# 99  572 min     8.6    266,241
#
# [100 rows x 6 columns]

# %% [markdown]
# 8. Details of Datasets from UCI machine learning repositories.
# Url = https://archive.ics.uci.edu/
# You have to find the following details:
#
#   A) Dataset name
#
#   B) Data type
#
#   C) Task
#
#   D) Attribute type
#
#   E) No of instances
#
#   F) No of attribute G) Year
#
#   Note: - from the home page you have to go to the Show All Dataset page through code.

# %%
# Importing Libraries
import pandas as pd
import selenium                                  
from bs4 import BeautifulSoup
from selenium import webdriver                   
from selenium.webdriver.common.by import By      

import warnings                                  
warnings.filterwarnings("ignore")

import time                                      
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service

#Importing required exceptions which needs to be handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException, ElementClickInterceptedException

# Let's Install automated chrome browser and connect it to web driver
driver = webdriver.Chrome(service=Service())

#maximise the window
driver.maximize_window()

# %%
#opening the website page
driver.get("https://archive.ics.uci.edu/")

# %%
#clicking all dataset
dataset=driver.find_element(By.XPATH,'/html/body/div/div[1]/div[1]/header/nav/ul/li[1]/a')
dataset.click()

# %%
#Clicking collapse
collapse=driver.find_element(By.XPATH,'//label[@class="btn-primary btn-sm btn flex gap-2 rounded-full"]')
collapse.click()

# %%
name=[]
datatype=[]
task=[]
instances=[]

while True:
    
    #Extracting Name:
    for i in driver.find_elements(By.XPATH,'//h2[@class="truncate text-primary"]'):
        name.append(i.text)
    
    #Extracting DataType
    for i in driver.find_elements(By.XPATH,'//div[@class="relative col-span-8 sm:col-span-7"]/div/div[2]'):
        datatype.append(i.text)
        
    #Extracting task
    for i in driver.find_elements(By.XPATH,'//div[@class="relative col-span-8 sm:col-span-7"]/div/div[1]'):
        task.append(i.text)
         
    #Extracting instances
    for i in driver.find_elements(By.XPATH,'//div[@class="relative col-span-8 sm:col-span-7"]/div/div[3]'):
        instances.append(i.text)
  
    #clicking next button
    try:
        nextButton= driver.find_element(By.XPATH,'//button[@class="btn-primary btn-sm btn"][2]')
        nextButton.click()
        time.sleep(3)
    except (NoSuchElementException, ElementClickInterceptedException):
        break

driver.close()
Attributetype=attributetype[:624]
print(len(name),len(datatype),len(task),len(instances),len(no_attribute), len(Attributetype), len(year))

#Creating DataFrame:
data=pd.DataFrame({
    "Dataset Name":name,
    "Data Type":datatype,
    "Task":task,
    "No of Instances":instances})
data
# Out:
# 10 10 10 10 10 20 10
#                            Dataset Name     Data Type            Task  \
# 0                                  Iris       Tabular  Classification
# 1                         Heart Disease  Multivariate  Classification
# 2                                 Adult  Multivariate  Classification
# 3                      Dry Bean Dataset  Multivariate  Classification
# 4                              Diabetes
# 5                                  Wine       Tabular  Classification
# 6  Breast Cancer Wisconsin (Diagnostic)  Multivariate  Classification
# 7                        Car Evaluation  Multivariate  Classification
# 8            Rice (Cammeo and Osmancik)  Multivariate  Classification
# 9                              Mushroom  Multivariate  Classification
#
#     No of Instances
# 0     150 Instances
# 1     303 Instances
# 2  48.84K Instances
# 3  13.61K Instances
# 4
# 5     178 Instances
# 6     569 Instances
# 7   1.73K Instances
# 8   3.81K Instances
# 9   8.12K Instances
